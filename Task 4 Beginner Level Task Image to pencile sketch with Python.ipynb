# %% [markdown]
# # LetsGrowMore: Data Science

# %% [markdown]
# # Task 4 : [Beginner Level Task] Image to pencile sketch with Python.

# %% [markdown]
# # Name of Intern: Payal Rakhama Paymode

# %% [markdown]
# # Importing packages and libraries

# %%
pip install opencv-python
# Out:
# Collecting opencv-pythonNote: you may need to restart the kernel to use updated packages.
#
#   Downloading opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
#                                               0.0/38.2 MB ? eta -:--:--
#                                               0.4/38.2 MB 9.2 MB/s eta 0:00:05
#      -                                        1.0/38.2 MB 12.9 MB/s eta 0:00:03
#      -                                        1.8/38.2 MB 11.4 MB/s eta 0:00:04
#      --                                       2.5/38.2 MB 13.0 MB/s eta 0:00:03
#      ---                                      2.9/38.2 MB 12.5 MB/s eta 0:00:03
#      ---                                      3.6/38.2 MB 12.7 MB/s eta 0:00:03
#      ----                                     4.1/38.2 MB 12.5 MB/s eta 0:00:03
#      ----                                     4.8/38.2 MB 12.6 MB/s eta 0:00:03
#      -----                                    5.2/38.2 MB 12.2 MB/s eta 0:00:03
#      -----                                    5.6/38.2 MB 12.4 MB/s eta 0:00:03
#      ------                                   6.1/38.2 MB 11.8 MB/s eta 0:00:03
#      ------                                   6.5/38.2 MB 11.9 MB/s eta 0:00:03
#      -------                                  7.1/38.2 MB 11.6 MB/s eta 0:00:03
#      -------                                  7.4/38.2 MB 11.8 MB/s eta 0:00:03
#      -------                                  7.4/38.2 MB 11.8 MB/s eta 0:00:03
#      -------                                  7.4/38.2 MB 11.8 MB/s eta 0:00:03
#      -------                                  7.4/38.2 MB 11.8 MB/s eta 0:00:03
#      -------                                  7.5/38.2 MB 8.9 MB/s eta 0:00:04
#      --------                                 7.9/38.2 MB 9.2 MB/s eta 0:00:04
#      --------                                 8.1/38.2 MB 8.7 MB/s eta 0:00:04
#      --------                                 8.6/38.2 MB 8.7 MB/s eta 0:00:04
#      ---------                                8.7/38.2 MB 8.4 MB/s eta 0:00:04
#      ---------                                8.9/38.2 MB 8.3 MB/s eta 0:00:04
#      ---------                                9.2/38.2 MB 8.2 MB/s eta 0:00:04
#      ----------                               9.8/38.2 MB 8.2 MB/s eta 0:00:04
#      ----------                               9.9/38.2 MB 8.0 MB/s eta 0:00:04
#      -----------                              10.6/38.2 MB 8.2 MB/s eta 0:00:04
#      -----------                              10.8/38.2 MB 7.9 MB/s eta 0:00:04
#      -----------                              11.0/38.2 MB 7.8 MB/s eta 0:00:04
#      -----------                              11.1/38.2 MB 7.7 MB/s eta 0:00:04
#      -----------                              11.2/38.2 MB 7.4 MB/s eta 0:00:04
#      -----------                              11.3/38.2 MB 7.3 MB/s eta 0:00:04
#      -----------                              11.4/38.2 MB 7.0 MB/s eta 0:00:04
#      -----------                              11.4/38.2 MB 6.8 MB/s eta 0:00:04
#      ------------                             11.6/38.2 MB 6.7 MB/s eta 0:00:04
#      ------------                             11.7/38.2 MB 6.5 MB/s eta 0:00:05
#      ------------                             11.7/38.2 MB 6.4 MB/s eta 0:00:05
#      ------------                             11.9/38.2 MB 6.2 MB/s eta 0:00:05
#      ------------                             12.0/38.2 MB 6.1 MB/s eta 0:00:05
MB 9.4 MB/s eta 0:00:01
#      ---------------------------------        31.8/38.2 MB 9.2 MB/s eta 0:00:01
#      ---------------------------------        32.3/38.2 MB 9.5 MB/s eta 0:00:01
#      ----------------------------------       32.6/38.2 MB 9.1 MB/s eta 0:00:01
#      ----------------------------------       33.0/38.2 MB 9.0 MB/s eta 0:00:01
#      ----------------------------------       33.4/38.2 MB 9.0 MB/s eta 0:00:01
#      -----------------------------------      33.8/38.2 MB 9.0 MB/s eta 0:00:01
#      -----------------------------------      34.3/38.2 MB 9.2 MB/s eta 0:00:01
#      ------------------------------------     34.9/38.2 MB 9.4 MB/s eta 0:00:01
#      ------------------------------------     35.0/38.2 MB 9.4 MB/s eta 0:00:01
#      ------------------------------------     35.3/38.2 MB 9.0 MB/s eta 0:00:01
#      -------------------------------------    35.6/38.2 MB 9.1 MB/s eta 0:00:01
#      -------------------------------------    35.9/38.2 MB 8.7 MB/s eta 0:00:01
#      --------------------------------------   36.6/38.2 MB 8.8 MB/s eta 0:00:01
#      --------------------------------------   36.9/38.2 MB 9.0 MB/s eta 0:00:01
#      --------------------------------------   37.0/38.2 MB 8.7 MB/s eta 0:00:01
#      --------------------------------------   37.0/38.2 MB 8.7 MB/s eta 0:00:01
#      --------------------------------------   37.0/38.2 MB 8.7 MB/s eta 0:00:01
#      --------------------------------------   37.1/38.2 MB 7.7 MB/s eta 0:00:01
#      --------------------------------------   37.2/38.2 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  37.4/38.2 MB 7.3 MB/s eta 0:00:01
#      ---------------------------------------  37.8/38.2 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  38.0/38.2 MB 7.2 MB/s eta 0:00:01
#      ---------------------------------------  38.2/38.2 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------  38.2/38.2 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------  38.2/38.2 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------- 38.2/38.2 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in c:\users\pintu paymode\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72

# %%
import cv2
import matplotlib.pyplot as plt 
plt.style.use ("seaborn-v0_8")

# %% [markdown]
# # Loading Original Image

# %%
Image = cv2.imread(r"C:\Users\PINTUP~1\AppData\Local\Temp\Rar$DIa16304.22172\daisy_pollen_flower.jpg")
Image = cv2.cvtColor(Image,cv2.COLOR_BGR2RGB) 
plt.figure(figsize=(10,10))
plt.imshow(Image)
plt.axis("off")
plt.title( "Original Image")
plt.show()

# %% [markdown]
# # Converting image to grey scale

# %%
Image_gray = cv2.cvtColor(Image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10, 10))
plt.imshow(Image_gray,cmap="gray")
plt.axis("off") 
plt.title("Grayscale Image")
plt.show()

# %% [markdown]
# # Invert the new grayscale image

# %%
Image_invert=cv2.bitwise_not(Image_gray)
plt.figure(figsize=(8,8)) 
plt.imshow(Image_invert,cmap="gray")
plt.title("Inverted Image")
plt.axis("off") 
plt.show()

# %%
Image_smoothing=cv2.GaussianBlur(Image_invert,(21, 21),sigmaX=0,sigmaY=0)
plt.figure(figsize=(10,10)) 
plt.imshow(Image_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothened Image")
plt.show()

# %% [markdown]
# # Converting image to pencil sketch

# %%
sketch = cv2.divide(Image_gray, 255-Image_smoothing, scale=255)
plt.figure(figsize=(10,10)) 
plt.imshow(sketch,cmap="gray") 
plt.axis("off")
plt.title("Pencilsketch Image")
plt.show()
